# %%
# Example of class object and instance
class BankAccount:
    bank_name = "ABC Bank"   # class variable

    def __init__(self, account_holder, balance):
        self.account_holder = account_holder  # instance variable
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount
        print(f"{amount} deposited. New balance: {self.balance}")

    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            print(f"{amount} withdrawn. Remaining balance: {self.balance}")
        else:
            print("Insufficient balance")

    def display_details(self):
        print(f"Name: {self.account_holder}")
        print(f"Bank: {BankAccount.bank_name}")
        print(f"Balance: {self.balance}")

# %%
acc1 = BankAccount("Rahul", 5000)
acc2 = BankAccount("Anita", 10000)

acc1.deposit(2000)
acc2.withdraw(3000)
acc1.display_details()
# Out:
# 2000 deposited. New balance: 7000
# 3000 withdrawn. Remaining balance: 7000
# Name: Rahul
# Bank: ABC Bank
# Balance: 7000

# %%
# Inheritance
class Employee:
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary

    def get_salary(self):
        return self.salary


class Developer(Employee):
    def get_salary(self):
        return self.salary + 5000   # bonus


class Manager(Employee):
    def get_salary(self):
        return self.salary + 10000  # bonus

# %%
# polymorphism
employees = [
    Developer("Arjun", 40000),
    Manager("Priya", 50000)
]

for emp in employees:
    print(emp.name, "Salary:", emp.get_salary())
# Out:
# Arjun Salary: 45000
# Priya Salary: 60000

# %%
# Encapsulation
from abc import ABC, abstractmethod

class Payment(ABC):
    @abstractmethod
    def pay(self, amount):
        pass


class CreditCardPayment(Payment):
    def pay(self, amount):
        print(f"Paid {amount} using Credit Card")


class UpiPayment(Payment):
    def pay(self, amount):
        print(f"Paid {amount} using UPI")

# %%
# Abstraction
payment1 = CreditCardPayment()
payment2 = UpiPayment()

payment1.pay(1500)
payment2.pay(800)
# Out:
# Paid 1500 using Credit Card
# Paid 800 using UPI

# %%
# *args
def calculate_total(*args):
    total = 0
    for num in args:
        total += num
    print("Total:", total)

calculate_total(10, 20)
calculate_total(5, 10, 15)
# Out:
# Total: 30
# Total: 30

# %%
# *KWargs
def print_employee(**kwargs):
    for key, value in kwargs.items():
        print(key, ":", value)

print_employee(name="Bhavana", role="Developer", salary=70000)
# Out:
# name : Bhavana
# role : Developer
# salary : 70000

# %%
# *args and *KWargs
def order_food(*items, **details):
    print("Items ordered:")
    for item in items:
        print("-", item)

    print("Order details:")
    for key, value in details.items():
        print(key, ":", value)

order_food("Burger", "Pizza", customer="Bhavana", payment="Card")
# Out:
# Items ordered:
# - Burger
# - Pizza
# Order details:
# customer : Bhavana
# payment : Card
